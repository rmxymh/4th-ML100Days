# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function

# %%
'''
需要執行初始值設定, 下列三個
# Learning rate
#iteration counter
#Step size  
'''
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''
# Out:
# '\nwhile previous_step_size > precision and iters < max_iters:\n\n  算法迭代更新\n\nprint("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations\n'

# %%
learning_rates = [0.1, 0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001] # Learning rate

# %%
def gradient_calculation(lr):
    cur_x = 3 # The algorithm starts at x=3
    previous_step_size = 1
    iters = 0 #iteration counter
    
    iters_history = [iters]
    x_history = [cur_x]
    
    while previous_step_size > precision and iters < max_iters:
        prev_x = cur_x #Store current x value in prev_x
        cur_x = cur_x - lr * df(prev_x) #Gradient descent
        previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
        iters = iters+1 #iteration count
         # Store parameters for plotting
        iters_history.append(iters)
        x_history.append(cur_x)
    print("the learning rate is", lr, "\nIteration",iters,"\nX value is", cur_x)
    return (iters_history, x_history)

# %%
iters_histories = {}
x_histories = {}

for lr in learning_rates:
    (iters_history, x_history) = gradient_calculation(lr)
    iters_histories[lr] = iters_history
    x_histories[lr] = x_history
# Out:
# the learning rate is 0.1
# Iteration 66
# X value is -4.999996786123911
# the learning rate is 0.05
# Iteration 131
# X value is -4.999991893027057
# the learning rate is 0.01
# Iteration 595
# X value is -4.9999518490318176
# the learning rate is 0.005
# Iteration 1125
# X value is -4.999901670482245
# the learning rate is 0.001
# Iteration 4837
# X value is -4.999501668667748
# the learning rate is 0.0005
# Iteration 8984
# X value is -4.999001297333986
# the learning rate is 0.0001
# Iteration 10000
# X value is -3.917534277778167

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

def plot(lr, iters_history, x_history):
    plt.plot(iters_history, x_history, 'o-', ms=3, lw=1, color='black')
    plt.xlabel(r'$iters$', fontsize=16)
    plt.ylabel(r'$x$', fontsize=16)
    plt.title('Learning Rate = %f' % (lr))
    plt.show()

# %%
plot(0.1, iters_histories[0.1], x_histories[0.1])

# %%
plot(0.05, iters_histories[0.05], x_histories[0.05])

# %%
plot(0.01, iters_histories[0.01], x_histories[0.01])

# %%
plot(0.005, iters_histories[0.005], x_histories[0.005])

# %%
plot(0.001, iters_histories[0.001], x_histories[0.001])

# %%
plot(0.0005, iters_histories[0.0005], x_histories[0.0005])

# %%
plot(0.0001, iters_histories[0.0001], x_histories[0.0001])
